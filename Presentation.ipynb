# %%
import plotly
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
import requests as r

plotly.tools.set_credentials_file(username='manuel.morais', api_key='P28dLUsfuAlaxoyftdlw')

# %%
df = pd.read_csv('coinbaseUSD_1-min_data_2014-12-01_to_2018-11-11.csv')

# %%
df['timestamp'] = pd.to_datetime(df['Timestamp'],unit='s')
df.drop('Timestamp',axis=1,inplace = True)
df['Date'] = df.timestamp.dt.date
df = df.set_index('timestamp');

# %%
df = df.resample('D').mean()

# %%
df = df.interpolate()

# %%
df
# Out:
#                    Open         High          Low        Close  Volume_(BTC)  \
# timestamp
# 2014-12-01   335.000000   335.000000   335.000000   335.000000      0.014139
# 2014-12-02   377.821429   377.857143   377.821429   377.857143      2.144800
# 2014-12-03   377.818333   377.818333   377.818333   377.818333      0.091101
# 2014-12-04   377.100000   377.100000   377.100000   377.100000      0.010000
# 2014-12-05   377.550000   377.550000   377.550000   377.550000      0.012500
# 2014-12-06   378.000000   378.000000   378.000000   378.000000      0.015000
# 2014-12-07   376.505000   376.505000   376.500000   376.500000      0.125000
# 2014-12-08   375.010000   375.010000   375.000000   375.000000      0.235000
# 2014-12-09   377.130000   377.130000   377.125000   377.125000      0.122500
# 2014-12-10   379.250000   379.250000   379.250000   379.250000      0.010000
# 2014-12-11   371.436250   371.436250   371.373750   371.373750      0.398750
# ...

# %%
trace_Price = go.Scatter()

data = [trace_Price]

fig = dict(data=data)
py.iplot(fig, filename = "Bitcoin_Market_Price copy", fileopt='extend')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~manuel.morais/58.embed" height="525px" width="100%"></iframe>

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
trace1 = go.Scatter(
        x =[1, 2],
        y =[1, 2],
        mode = 'lines+markers'
)

trace2 = go.Scatter(
        x =[3, 4],
        y =[3, 4],
        mode = 'lines+markers'
)

trace3 = go.Scatter(
        x =[1,2,None,4,5],
        y =[1,2,None,4,5],
        mode = 'lines+markers'
)

data = [trace3]

fig = dict(data=data)
py.iplot(fig, filename = "Experiment")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~manuel.morais/62.embed" height="525px" width="100%"></iframe>
