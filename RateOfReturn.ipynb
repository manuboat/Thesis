# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import timeit

from utils import utils_v2
plt.rcParams['figure.figsize'] = (15, 7) 
# %matplotlib inline


data = pd.read_csv('coinbaseUSD_1-min_data_2014-12-01_to_2018-06-27.csv')

# %%
data.tail()
# Out:
#           Timestamp     Open     High      Low    Close  Volume_(BTC)  \
# 1819069  1530057360  6064.03  6080.00  6064.03  6080.00     10.561973
# 1819070  1530057420  6080.00  6080.00  6071.52  6077.99      0.682001
# 1819071  1530057480  6078.00  6081.00  6077.99  6081.00      5.710185
# 1819072  1530057540  6081.00  6085.70  6074.00  6074.00     20.892658
# 1819073  1530057600  6074.01  6074.01  6071.52  6071.53     33.898112
#
#          Volume_(Currency)  Weighted_Price
# 1819069       64148.832294     6073.564990
# 1819070        4145.298155     6078.136687
# 1819071       34708.629492     6078.372515
# 1819072      127050.449960     6081.105271
# 1819073      205896.111310     6073.969960

# %%
data['simple_return'] = (data['Weighted_Price']/data['Weighted_Price'].shift(1))-1

# %%
data['simple_return'].iloc[-100000:].plot(figsize=(10,5));

# %%
data['Weighted_Price'].plot();
