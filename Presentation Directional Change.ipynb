# %% [markdown]
# # Directional Change #

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython import display
from ipywidgets import interact, widgets

# %matplotlib inline

data = pd.read_csv('coinbaseUSD_1-min_data_2014-12-01_to_2018-06-27.csv')

data['timestamp'] = pd.to_datetime(data['Timestamp'],unit='s')
data.drop('Timestamp',axis=1,inplace = True)
data['Date'] = data.timestamp.dt.date
data = data.set_index('timestamp');

# %%
def plot(year,month,day,freq):
    data.loc[str(year)+' '+ month +' '+ str(day)].resample(freq,closed='right',label='right')['Weighted_Price'].mean().plot(figsize=(16,5));
    data.loc[str(year)+' '+ month +' '+ str(day)]['Weighted_Price'].plot(figsize=(16,5));
    sample = data.loc[str(year)+' '+ month +' '+ str(day)].resample(freq,closed='right',label='right').mean().index
    for xc in sample:
        plt.axvline(x=xc,c='k',linewidth=0.5,linestyle='--')
    plt.axis(xmin=sample[0] , xmax= sample[-1]);

# %%
interact(plot, year = widgets.IntSlider(min=2014,max=2018,step=1,value=2016),month = widgets.SelectionSlider(options=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], value='Jan',), day = widgets.IntSlider(min=1,max=30,step=1,value=3),freq =widgets.Text(value='H'))
# Out:
# interactive(children=(IntSlider(value=2016, description='year', max=2018, min=2014), SelectionSlider(descripti…
# <function __main__.plot(year, month, day, freq)>

# %%
data.loc['2017 Jan 3 15:00':'2017 Jan 4 00:00':]
# Out:
#                         Open     High      Low    Close  Volume_(BTC)  \
# timestamp
# 2017-01-03 15:00:00  1013.65  1013.65  1013.55  1013.55     11.068032
# 2017-01-03 15:01:00  1013.49  1013.62  1012.73  1013.37      3.852055
# 2017-01-03 15:02:00  1012.91  1014.00  1012.90  1014.00      0.920878
# 2017-01-03 15:03:00  1013.99  1014.12  1013.99  1014.12      0.446880
# 2017-01-03 15:04:00  1014.29  1014.44  1014.29  1014.44     10.040000
# 2017-01-03 15:05:00  1014.28  1014.39  1014.28  1014.30      5.377180
# 2017-01-03 15:06:00  1014.30  1014.30  1012.98  1014.00      1.187400
# 2017-01-03 15:07:00  1013.71  1014.01  1012.98  1014.01      0.974640
# 2017-01-03 15:08:00  1014.01  1014.45  1014.01  1014.45      1.240450
# 2017-01-03 15:09:00  1014.50  1014.50  1013.86  1013.86      5.439630
# 2017-01-03 15:10:00  1014.46  1014.92  1014.46  1014.66      8.617240
# 2017-01-03 15:11:00  1014.75  1015.33  1014.25  1015.33      3.530220
# ...
