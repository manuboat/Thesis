# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

import plotly.plotly as py
import plotly.graph_objs as go

import requests

from utils import utils_v2
plt.rcParams['figure.figsize'] = (15, 7) 
# %matplotlib inline
# %load_ext autoreload
# %autoreload

# %%
data = pd.read_csv('coinbaseUSD_1-min_data_2014-12-01_to_2018-06-27.csv')

# %%
data['timestamp'] = pd.to_datetime(data['Timestamp'],unit='s')
data.drop('Timestamp',axis=1,inplace = True)
data['Date'] = data.timestamp.dt.date
data = data.set_index('timestamp');

# %%
date = '2017 Dec 10'
    
stock_series = data.loc[date]['Weighted_Price']

DCA, CPA = utils_v2.get_events(stock_series,threshold = 0.05)
    
utils_v2.plot_events(stock_series,DCA,CPA)

# %%
DDCstar, DDCstar_time  = utils_v2.theoretical_CP(stock_series, DCA, CPA, threshold = 0.05)

# %%
values_up,index_up,values_down, index_down, OS_values, OS_index = utils_v2.data_plot(stock_series, DDCstar, DDCstar_time, DCA, CPA)

# %%
r = requests.get('https://plot.ly/~manuel.morais/82.json')

t = r.json()

layout = t['layout']

# %%
t['data'][0]['x']=stock_series.index
t['data'][0]['y']=stock_series.values
t['data'][1]['x']=OS_index
t['data'][1]['y']=OS_values
t['data'][2]['x']=index_down
t['data'][2]['y']=values_down
t['data'][3]['x']=index_up
t['data'][3]['y']=values_up

# %%
updatemenus = list([
    dict(type="buttons",
         active=-1,
         buttons=list([
            dict(label = 'Price',
                 method = 'update',
                 args = [{'visible': [True, False, False, False]}]),
            dict(label = 'Overshoot',
                 method = 'update',
                 args = [{'visible': [False, True, False, False]}]),
            dict(label = 'Down',
                 method = 'update',
                 args = [{'visible': [False, False, True, False]}]),
            dict(label = 'Up',
                 method = 'update',
                 args = [{'visible': [False, False, False, True]}])
        ]),
    )
])

# %%
t['layout']['updatemenus'] = updatemenus

# %%
fig = dict(data=t['data'],layout=t['layout'])
py.iplot(fig, filename = "New")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~manuel.morais/133.embed" height="525px" width="100%"></iframe>

# %%
table = pd.DataFrame(columns=['NDC','PC','Median_OSV_down','Median_OSV_up','Median_OSV_overall','Median_TM_up','Median_TM_down','Median_TM_overall','Median_T_overall','Median_T_down','Median_T_up','Median_R_DC_down','Median_R_DC_up','Median_R_DC_overall','LenC','Mean_LenC'])

# %%
table, OSV, T, TM = utils_v2.event_summary(stock_series,DCA,CPA,table,threshold =  0.05)

# %%
table
# Out:
#                 LenC  Mean_LenC  Median_OSV_down  Median_OSV_overall  \
# 2017-12-10  9.529406   2.382352        -1.008673             1.17349
#
#             Median_OSV_up  Median_R_DC_down  Median_R_DC_overall  \
# 2017-12-10       1.720442         -1.008673             0.000006
#
#             Median_R_DC_up  Median_TM_down  Median_TM_overall  Median_TM_up  \
# 2017-12-10        1.720442       -1.958239           2.161882      2.806464
#
#            Median_T_down Median_T_overall Median_T_up NDC        PC
# 2017-12-10      06:14:30         06:14:30    05:18:00   5  1.056343

# %%
OSV_up = [value for value in OSV if value >= 0]
OSV_down = [value for value in OSV if value < 0]

# %%
OSV_down = pd.DataFrame(OSV_down,columns= ['OSV_down'])
OSV_up = pd.DataFrame(OSV_up,columns= ['OSV_up'])

# %%
OSV_DataFrame = OSV_up.describe()
OSV_DataFrame['OSV_down'] = OSV_down.describe()

# %%
OSV_DataFrame
# Out:
#          OSV_up  OSV_down
# count  2.000000  2.000000
# mean   1.720442 -1.008673
# std    1.101828  0.561408
# min    0.941332 -1.405648
# 25%    1.330887 -1.207160
# 50%    1.720442 -1.008673
# 75%    2.109997 -0.810185
# max    2.499552 -0.611697

# %%
trace_up = go.Histogram(
    x= OSV_up.values
)

trace_down = go.Histogram(
    x= OSV_down.values
)

dt = [trace_up, trace_down]

py.iplot(dt, filename='basic hist')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~manuel.morais/211.embed" height="525px" width="100%"></iframe>

# %%
trace_up = go.Box(
    y= OSV_up.values*0.001
)

trace_down = go.Box(
    y= OSV_down.values*0.001
)

dt = [trace_up, trace_down]
py.iplot(dt)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~manuel.morais/213.embed" height="525px" width="100%"></iframe>

# %%
subA_DCA, subA_CPA = utils_v2.get_sub_events(stock_series, DCA, CPA, threshold = 0.05)

# %%
utils_v2.plot_events(stock_series,subA_DCA[0],subA_CPA[0])
utils_v2.plot_events(stock_series,subA_DCA[1],subA_CPA[1])

utils_v2.plot_events(stock_series,DCA,CPA)
